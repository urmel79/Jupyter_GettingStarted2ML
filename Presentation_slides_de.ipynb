# %% [markdown]
# # Eine systematische Einführung in das Maschinelle Lernen (ML)

# %%
#Import library for displaying images
from IPython.display import Image

# %%
Image(filename = "./images/Cover_image.png", width = 1200)

# %% [markdown]
# ## Ziele des Workshops

# %% [markdown]
# ## Eine kurze Einführung

# %% [markdown]
# ## Überblick über die Hauptschritte
#
# Die folgenden **Schritte des systematischen ML-Prozesses** werden in den Hauptabschnitten des Tutorials [Step-by-step_intro_to_ML_with_SVC_and_Iris.ipynb](./Step-by-step_intro_to_ML_with_SVC_and_Iris.ipynb) behandelt:

# %% [markdown]
# - STEP 0: Select hardware and software suitable for ML
# - STEP 1: Acquire the ML dataset
# - STEP 2: Explore the ML dataset
# - STEP 3: Choose and create the ML model
# - STEP 4: Preprocess the dataset for training
# - STEP 5: Carry out training, prediction and testing
# - STEP 6: Evaluate model's performance
# - STEP 7: Vary parameters of the ML model manually
# - STEP 8: Tune the ML model systematically

# %% [markdown]
# ## STEP 0: Select hardware and software suitable for ML
#
# **Ziel:** Hinweise für die Auswahl von ***Hardware*** und ***Software***, die für maschinelles Lernen geeignet sind

# %% [markdown]
# ### Auf **Community Support** achten
#
# - neben rein technischen oder finanziellen Merkmalen sollte auch auf eine breite **Unterstützung durch eine gut vernetzte Community** geachtet werden:
#     - ausgewogener Anteil aus **Herstellern** von Hardwarekomponenten,
#     - **Softwareentwickler** idealerweise aus dem **Open-Source-**Ökosystem und
#     - eine aktive **Nutzer-Community**
# - ohne Unterstützung einer aktiven Community ist man bei Fragen oder Problemen (fast) auf sich allein gestellt
# - Empfehlung: Entscheiden Sie sich für die (technisch, preislich, etc.) **zweitbeste Alternative**, aber dafür mit einer großen **Community**!

# %% [markdown]
# ### Auswahl geeigneter **Hardware**
#
# Unterscheidung in:
#
# - **Trainingssystem**
# - **Applikationssystem**

# %% [markdown]
# ### Auswahl geeigneter **Software** (1)
#
# - Programmiersprachen
# &rarr; Erkenntnis: Es gibt **keine beste Programmiersprache für maschinelles Lernen**, jede ist dort gut, wo sie am besten passt.
#
# Folgendes **Trenddiagramm** zeigt die **Beliebtheit von Programmiersprachen** für ML (Quelle: [Stack Overflow Trends](https://insights.stackoverflow.com/trends?tags=python%2Cr%2Coctave%2Cjava%2Cc%2B%2B), Lizenz: CC BY-SA 4.0):

# %%
Image(filename = "./images/2022-09-07_StackOverflowTrends_ProgrammingLanguages_wide.png", width = 1000)

# %% [markdown]
# ### Auswahl geeigneter **Software** (2)
#
# - Python-Pakete für:
#     - Datenanalyse
#     - Datenvisualisierung
#     - maschinenelles Lernen
#
# Folgendes **Trenddiagramm** zeigt die **Beliebtheit** ausgewählter **Python-Pakete** für **Datenanalyse**, **Datenvisualisierung** und **maschinelles Lernen** (Quelle: [Stack Overflow Trends](https://insights.stackoverflow.com/trends?tags=pandas%2Ctensorflow%2Cnumpy%2Ckeras%2Cscikit-learn%2Cmatplotlib), Lizenz: CC BY-SA 4.0):

# %%
Image(filename = "./images/2022-09-07_StackOverflowTrends_MLPythonPackages_wide.png", width = 1000)

# %% [markdown]
# ### Auswahl geeigneter **Software** (3)
#
# - Programmier- und Entwicklungsumgebungen (sog. IDEs)
#
# Folgendes **Trenddiagramm** zeigt die **Beliebtheit** ausgewählter **IDEs** für ML-Programmiersprachen (Quelle: [Stack Overflow Trends](https://insights.stackoverflow.com/trends?tags=rstudio%2Cjupyter-notebook%2Cvisual-studio-code), Lizenz: CC BY-SA 4.0):

# %%
Image(filename = "./images/2022-09-07_StackOverflowTrends_IDEs_wide.png", width = 1000)

# %% [markdown]
# ### Auswahl geeigneter **Software** (4)
#
# - Cloud-hosted IDEs
#     - interessant, um Dinge auszuprobieren (ohne eigene Hardware und Software)
#     &rarr; **Wichtig:** Datenschutz-Aspekte beachten!

# %% [markdown]
# ### Auswahl geeigneter **Software** (5)
#
# - Betriebsysteme:
#     Arbeitsplatzrechner &lrarr; virtuelle Maschine &rarr; separater **Laborrechner**!
#
# Folgendes **Trenddiagramm** zeigt die **Beliebtheit** Betriebssysteme, die von **Datenanalysten** und **ML-Entwicklern** verwendet werden (Quelle: [Stack Overflow Trends](https://insights.stackoverflow.com/trends?tags=windows%2Clinux%2Cmacos), Lizenz: CC BY-SA 4.0):

# %%
Image(filename = "./images/2022-09-07_StackOverflowTrends_OperatingSystems_wide.png", width = 1000)

# %% [markdown]
# ## STEP 1: Acquire the ML dataset

# %%
Image(filename = "./images/Iris_images.png", width = 1500)

# %% [markdown]
# ## STEP 2: Explore the ML dataset

# %% [markdown]
# ## STEP 3: Choose and create the ML model

# %% [markdown]
# ## STEP 4: Preprocess the dataset for training

# %% [markdown]
# ## STEP 5: Carry out training, prediction and testing

# %% [markdown]
# ## STEP 6: Evaluate model's performance

# %% [markdown]
# ## STEP 7: Vary parameters of the ML model manually

# %% [markdown]
# ## STEP 8: Tune the ML model systematically

# %% [markdown]
# # Presentation mode
#
# Start presentation mode with:
#
# ```bash
# $ jupyter nbconvert SVM_MNIST_8x8_scikit.ipynb --to slides --post serve
# ```
#
# Refer to:
#
# - [RISE: Reveal.js - Jupyter/IPython Slideshow Extension](https://rise.readthedocs.io/en/maint-5.5/index.html)
#     - [Installation](https://rise.readthedocs.io/en/maint-5.5/installation.html)
#     - [Creating a slideshow](https://rise.readthedocs.io/en/maint-5.5/usage.html#creating-a-slideshow)
#     - [reveal: Config Options, Themes, Transitions ...](https://revealjs.com/themes/)
# - [Presenting Code Using Jupyter Notebook Slides](https://medium.com/@mjspeck/presenting-code-using-jupyter-notebook-slides-a8a3c3b59d67)
# - [5 Slides for Tips on Presentation Mode in Jupyter Notebook](https://towardsdatascience.com/5-slides-for-tips-on-presentation-mode-in-jupyter-notebook-f858b15fff4f)
